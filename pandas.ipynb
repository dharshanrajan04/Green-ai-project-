# %% [markdown]
# ##### pip install pandas

# %%
import pandas as pd

# %%
number_list=[22,33,44,55,66]
number_series=pd.Series(number_list,index=['a', 'b', 'c','d','e'],name="number")
print(number_series)
# Out:
# a    22
# b    33
# c    44
# d    55
# e    66
# Name: number, dtype: int64

# %%
std_dict={'name':['hari','tom','nath'],'age':[45,25,69]}
df=pd.DataFrame(std_dict)
print(df)
# Out:
#    name  age
# 0  hari   45
# 1   tom   25
# 2  nath   69

# %%
tips =pd.read_csv("d:/Users/Student/Desktop/dataset/tips.csv")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
import seaborn as sns

# %%
sns.displot(tips["total_bill"],kde=True)

# %%
sns.displot(tips["size"],kde=True)

# %%
sns.displot(tips["time"],kde=True)

# %%
sns.pairplot(tips)

# %%
tips1 = tips[["total_bill","tip","size"]]
sns.heatmap(tips1.corr(), annot= True)
# Out:
# <Axes: >

# %%
sns.barplot(x='sex',y='total_bill',data=tips)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sns.boxplot(x="day",y="total_bill",data=tips,palette='rainbow')
# Out:
# C:\Users\Student\AppData\Local\Temp\ipykernel_7348\3171212954.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="day",y="total_bill",data=tips,palette='rainbow')
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(x="day",y="total_bill",data=tips,palette='rainbow',hue="sex",)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>
